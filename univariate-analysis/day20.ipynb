# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('D:\MachineLearning-LearnByPractice\day20-univariate-analysis\IPL Matches 2008-2020.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Anand B Patil\AppData\Local\Temp\ipykernel_13628\3364135887.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('D:\MachineLearning-LearnByPractice\day20-univariate-analysis\IPL Matches 2008-2020.csv')

# %%
df.sample(10)
# Out:
#           id       city        date player_of_match  \
# 293   548353    Kolkata  2012-05-05       SP Narine
# 712  1175372  Bengaluru  2019-04-05      AD Russell
# 756  1216492  Abu Dhabi  2020-09-19       AT Rayudu
# 301   548361     Jaipur  2012-05-10   BW Hilfenhaus
# 583  1082597     Mumbai  2017-04-09          N Rana
# 356   598032     Jaipur  2013-04-27     JP Faulkner
# 684  1136609    Kolkata  2018-05-15   Kuldeep Yadav
# 207   501231     Jaipur  2011-04-29         J Botha
# 210   501234    Kolkata  2011-04-30   Iqbal Abdulla
# 354   598030    Chennai  2013-04-25        MS Dhoni
#
#                                venue  neutral_venue  \
# 293                     Eden Gardens              0
# 712            M.Chinnaswamy Stadium              0
# 756             Sheikh Zayed Stadium              0
# 301           Sawai Mansingh Stadium              0
# 583                 Wankhede Stadium              0
# 356           Sawai Mansingh Stadium              0
# ...

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(df['winner'])
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %% [markdown]
# ## b. PieChart

# %%
df['toss_decision'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <div style="border-top:black 2px solid"></div>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['result_margin'],bins=5)
# Out:
# (array([659.,  88.,  35.,  11.,   6.]),
#  array([  1.,  30.,  59.,  88., 117., 146.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## b. Distplot

# %%
sns.displot(df['result_margin'])

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(df['result_margin'])
# Out:
# <Axes: ylabel='result_margin'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704
